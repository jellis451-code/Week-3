# %% [markdown]
# <a href="https://colab.research.google.com/github/jellis451-code/Week-3/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Professional Bio Generator
# Goal: Practice variable assignment, string operations, and output formatting

# Step 1: Assign values to variables (name, goal, birth_year, current_year)
# Step 2: Calculate age
# Step 3: Create a border using string multiplication
# Step 4: Print the bio with top and bottom borders
